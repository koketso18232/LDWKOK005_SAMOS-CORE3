# %% [markdown]
# # Exercise E3
#
#   This notebook produces the following maps
#
# * The Antarctic continent and the Southern Ocean starting from 60°S
# * The South Atlantic, from 20°S to 50°S. The map should show the following locations: Walvis Bay, Cape Town, Rio de Janeiro, Montevideo

# %%
import cartopy.crs as ccrs
import cartopy
import cartopy.feature as cfeature
import matplotlib.pyplot as plt
import numpy as np
# these modules will be used later
from geopy.geocoders import Nominatim
from geopy.distance import geodesic

# %% [markdown]
# # Exercise 1: South Pole

# %%
plt.figure()
ax = plt.axes(projection=ccrs.SouthPolarStereo())
ax.coastlines()

ax.set_extent([-180, 180, -90, -60], ccrs.PlateCarree())

ax.add_feature(cfeature.LAND, facecolor='white')
ax.add_feature(cfeature.OCEAN, facecolor='lightblue')
ax.add_feature(cfeature.COASTLINE, linewidth=0.7)
ax.add_feature(cfeature.BORDERS, linestyle=':', linewidth=0.5)

theta = np.linspace(0, 2*np.pi, 100)
lon_circle = np.degrees(theta)
lat_circle = np.full_like(lon_circle, -60)

gl = ax.gridlines(draw_labels=True, linewidth=0.5, color='black', alpha=0.5)
gl.top_labels = False
gl.right_labels = False

ax.plot(lon_circle, lat_circle, transform=ccrs.PlateCarree(), color='black', linewidth=1.2)

plt.title("Antarctica and Southern Ocean (south of 60°S)", fontsize=10)

# %% [markdown]
# ## Exercise 2

# %%
geolocator = Nominatim(user_agent='educational')

# %%
# Step 1: Define coordinates for the cities
extent = [-60, 20, -50, -20]
central_lon = np.mean(extent[:2])
central_lat = np.mean(extent[2:])

place = ['Walvis Bay', 'Cape Town, South Africa',  'Rio de Janeiro',
    'Montevideo']
address = []
for p in place:
    loc = geolocator.geocode(p,language="en")
    address.append(loc)

# Step 2: Create the map figure and projection
fig = plt.figure(figsize=(14, 10))
ax = plt.axes(projection=ccrs.PlateCarree())
ax.set_extent(extent)

# Step 4: Add map features
ax.add_feature(cfeature.LAND, facecolor='lightgray')
ax.add_feature(cfeature.OCEAN, facecolor='lightblue')
ax.add_feature(cfeature.COASTLINE)
ax.add_feature(cfeature.BORDERS, linestyle=':')

# Step 5: Add gridlines and remove right/top labels
gl = ax.gridlines(draw_labels=True, linewidth=0.5, color='gray', alpha=0.5)
gl.right_labels = False   
gl.top_labels = False 

# Step 3: Set the geographic extent (South Atlantic region)
# Longitude range: Africa (-20°E) to South America (-60°W)
# Latitude range: 20°S to 50°S



# Step 6: Plot the cities and labels
for city, (lat, lon) in locations.items():
    ax.plot(lon, lat, marker='o', color='blue', markersize=6, transform=ccrs.PlateCarree())
    ax.text(lon + 1, lat - 1, city, fontsize=9, transform=ccrs.PlateCarree())

# Step 7: Add title
plt.title("Geographic Overview of the South Atlantic Ocean (20°S–50°S)", fontsize=12)

# Step 8: Display the map
plt.show()
